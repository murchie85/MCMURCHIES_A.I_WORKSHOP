# %% [markdown]
# # Percentiles & Moments

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # QUARTILE

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000) # GENERATE NORM DATA CENTERED AROUND 0 

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50) # THE POINT AT WHICH 50% OF THE DATA IS LESS THAN THIS GIVEN VALUE
# Out:
# 0.004082822571261039

# %%
np.percentile(vals, 90) # THE POINT AT WHICH 90% OF THE DATA IS LESS THAN THIS GIVEN VALUE
# Out:
# 0.6445863209047623

# %%
np.percentile(vals, 20)
# Out:
# -0.41574056705179296

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters when creating the test data. What effect does it have on the percentiles?

# %% [markdown]
# # Moments: Mean, Variance, Skew, Kurtosis
# Create a roughly normal-distributed random set of data:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## FIRST MOMENT = MEAN
# ## SECOND MOMENT = VARIANCE
# ## THIRD MOMENT = SKEW
# ## THIRD MOMENT = KURTOSIS

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# longer tail on left = negative skew
# longer tail on right = positive skew

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# how thick is the tail & how sharp is peak compared to normal distrobution

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %% [markdown]
# The first moment is the mean; this data should average out to about 0:

# %%
np.mean(vals)
# Out:
# 0.0029515864541076317

# %% [markdown]
# The second moment is the variance:

# %%
np.var(vals)
# Out:
# 0.2479857376373997

# %% [markdown]
# The third moment is skew - since our data is nicely centered around 0, it should be almost 0:

# %%
import scipy.stats as sp
sp.skew(vals)
# Out:
# 0.005406107467346704

# %% [markdown]
# The fourth moment is "kurtosis", which describes the shape of the tail. For a normal distribution, this is 0:

# %%
sp.kurtosis(vals)
# Out:
# -0.022116983492473263
